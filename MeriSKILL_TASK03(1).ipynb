# %% [markdown]
#  ### <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px"> MeriSKILL_Task_03(“HR Analytics")🌐🔍📝</div>

# %% [markdown]
#  ### <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px"> INTRODUCTION :</div>
#  #### Given a HR Analytics data  set we need to perform Exploratory data analysis in which we will perform Data Cleaning and Data Visualisation.

# %% [markdown]
#  ### <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px"> Data Description 🔍📊💡</div>
#  #### This dataset is originally from the National Institute of Diabetes and Digestive and KidneyDiseases. The objective of the dataset is to diagnostically predict whether a patient has diabetesbased on certain diagnostic measurements included in the dataset. Several constraints were placedon the selection of these instances from a larger database. In particular, all patients here are femalesat least 21 years old of Pima Indian heritage.2From the data set in the (.csv) File We can find several variables, some of them are independent(several medical predictor variables) and only one target dependent variable (Outcome).

# %% [markdown]
# ### <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px"> Import Libraries 📚</div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px">Loading data Set and Preprocessing Of Data(Data Cleaning)</div>

# %%
HR_data=pd.read_csv("C:\\Users\\Ujjaval Raj\\Downloads\\HR-Employee-Attrition.csv")
HR_data_head=HR_data.head()
HR_data_tail=HR_data.tail()
print(HR_data_head)
print(HR_data_tail)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# #### <font color='blue'>Checking for null values and duplicates</font>

# %%
HR_data_null=HR_data.isnull().sum()
HR_data_duplicate=HR_data.duplicated().sum()
print(HR_data_null)
print(HR_data_duplicate)
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #### <font color='blue'>Obtaining Datatypes and Describing data set with basic statistics</font>

# %%
HR_data.info()
HR_data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# #### <font color='blue'>Deleting column standardHours and Over18 as data is repeated for all rows(relundancy) .</font>

# %%
HR_data = HR_data.drop(columns=['Over18','StandardHours'])
HR_data.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                        1                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 34 columns]

# %% [markdown]
# #### <font color='blue'>Renaming the columns.</font>

# %%
HR_data = HR_data.rename(columns={'NumCompaniesWorked': 'NumberOfWorkedCompanies'})
HR_data.head(1)
# Out:
#    Age Attrition BusinessTravel  DailyRate Department  DistanceFromHome  \
# 0   41       Yes  Travel_Rarely       1102      Sales                 1
#
#    Education EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2  Life Sciences              1               1  ...
#
#    PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                        1                 0
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
#
# [1 rows x 34 columns]

# %% [markdown]
# #### <font color='blue'>Dropping Not available values (NAN).</font>

# %%
HR_data = HR_data.dropna()

# %% [markdown]
# ## <div style="text-align: center; background-color:skyblue ; font-family:Impact; color: purple; padding: 20px; line-height: 1;border-radius:10px">Visualisation of the HR data</div>

# %% [markdown]
# ### <font color='blue'>Plot a correlation map for all numeric variables</font>

# %%
numeric_columns = HR_data.select_dtypes(include=['float64', 'int64']).columns

# Calculate the correlation matrix for numeric columns only
correlation_matrix = HR_data[numeric_columns].corr()

sns.set_theme(style="whitegrid")

plt.figure(figsize=(12, 8))
cmap = sns.diverging_palette(240, 10, as_cmap=True)
sns.heatmap(correlation_matrix, annot=True, cmap=cmap, fmt=".2f", linewidths=.5)

plt.title('⚡ Correlation Map for Numeric Variables ⚡', fontsize=16, fontweight='bold')

plt.show()
# Out:
# C:\Users\Ujjaval Raj\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9889 (\N{HIGH VOLTAGE SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### <font color='blue'>Plot a correlation map for all numeric variables</font>

# %%
# Categorical Variables Visualizations
categorical_variables = ['Attrition','OverTime','BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']

sns.set_theme(style="whitegrid")

# Iterate through categorical variables for visualizations
for variable in categorical_variables:
    
    plt.figure(figsize=(10, 6))
    sns.countplot(x=variable, data=HR_data, palette='Set2')
    plt.title(f'📊 Distribution of {variable} 📊', fontsize=14, fontweight='bold')
    
    
    plt.show()
# Out:
# C:\Users\Ujjaval Raj\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Ujjaval Raj\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Ujjaval Raj\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Ujjaval Raj\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### <font color='blue'>Plot a correlation map for all numeric variables</font>

# %%
# Visualizations for numeric variables
numeric_variables = ['Age', 'DailyRate','TotalWorkingYears', 'Education', 'EducationField','EmployeeCount', 'DistanceFromHome']

for variable in numeric_variables:
    plt.figure(figsize=(10, 6))
    sns.histplot(HR_data[variable], bins=20, kde=True, color='skyblue')
    plt.title(f'Distribution of {variable}')
    plt.show()

# %% [markdown]
# ### <font color='blue'>Relation between Overtime and Age</font>

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='OverTime', y='Age', data=HR_data, palette='Set3')
plt.title('Relation between Overtime and Age')
plt.show()

# %% [markdown]
# ### <font color='blue'>Relation between BuisenessTravel and JObSatisfaction</font>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='BusinessTravel', y='JobSatisfaction', data=HR_data, palette='Blues')
plt.title('Business Travel vs. Job Satisfaction')
plt.show()

# %% [markdown]
# ### <font color='blue'>Relation between MaritalStatus and TotalWorkingYears</font>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='MaritalStatus', y='TotalWorkingYears', data=HR_data, palette='husl')
plt.title('Marital Status vs. Total Working Years')
plt.show()
